# %%
import csv
import tweepy
from tweepy import OAuthHandler

# %%
access_token = "1312044432175235072-0jSf5fmpdQTgDUj8uh9aosCMgHdPNc"
access_token_secret ="W26QSDin8BjeOAJkQ7CuunIzqFt9VMCSRhOW7tLB9e02i"
consumer_key ="pVC3vrgEkuQ7pfbQOECTyJfj6"
consumer_secret="6x0DpfZFDwd5O88FsEfYffWgiepheUzfNYIPDCRKxPCjayfGco"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret) 
auth.set_access_token(access_token, access_token_secret) 
api = tweepy.API(auth, wait_on_rate_limit = True)

csvFile = open('#svprwt.csv', 'a')
csvWriter = csv.writer(csvFile)

for tweet in tweepy.Cursor(api.search,
                           q =["#saveperawatindonesia"],
                           count=500,
                           lang="id",
                           since="2021-04-16",
                           tweet_mode = 'extended',
                           trucated='false').items():
    tweettext = str(tweet.full_text.lower().encode('ascii',errors='ignore'))
    if tweettext.startswith("rt @") == False and hasattr(tweet, 'retweeted_status') == False:
        print(tweet.user.id, tweet.created_at, tweet.id, tweet.full_text)
        csvWriter.writerow([tweet.created_at, tweet.full_text.encode('utf-8')])
csvFile.close()
# Out:
# 546638804 2021-04-17 08:13:00 1383332653164765191 Membuka mata dan yang pertama kali dilihat....
#
# #SavePerawatIndonesia yuni shara https://t.co/pUvZsFvDwz
# 1350310480192000001 2021-04-17 08:12:25 1383332508075388928 Memiliki 10 Game dalam 1 user id Hanya di RajaBandarQ
# Bonus Cashback 0.5%
# Bonus Referral 20%
# Live Chat : rajamantap,com , net
# WA : +855-88-654-8950
# Line : cs_rajabandarq
# Menerima Deposit Via PULSA
# #RajaBandarQ #SavePerawatIndonesia #PENTAGON #YuniShara https://t.co/zbhRSfi6sV
# 1333624981247250432 2021-04-17 08:12:12 1383332454237233158 Mamanya si balita yang terlalu membesar-besarkan situasi yg sesuai dengan ilmu kesehatan? Suami mengikuti istri yang tidak memiliki pemahaman akan dunia medis? Istrinya yang membawa suaminya berakhir di penjara hanya karena merasa paling pintar sedunia. #SavePerawatIndonesia https://t.co/OUPFjJU3Vg
# 1349570549790371840 2021-04-17 08:11:19 1383332229405810698 Selow aje....
#
# Yuni Shara
# #SavePerawatIndonesia
# ...

# %%
access_token = "1312044432175235072-0jSf5fmpdQTgDUj8uh9aosCMgHdPNc"
access_token_secret ="W26QSDin8BjeOAJkQ7CuunIzqFt9VMCSRhOW7tLB9e02i"
consumer_key ="pVC3vrgEkuQ7pfbQOECTyJfj6"
consumer_secret="6x0DpfZFDwd5O88FsEfYffWgiepheUzfNYIPDCRKxPCjayfGco"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret) 
auth.set_access_token(access_token, access_token_secret) 
api = tweepy.API(auth, wait_on_rate_limit = True)

csvFile = open('#satpolpp.csv', 'a')
csvWriter = csv.writer(csvFile)

for tweet in tweepy.Cursor(api.search,
                           q =["Satpol PP"],
                           count=500,
                           lang="id",
                           since="2021-04-16",
                           tweet_mode = 'extended',
                           trucated='false').items():
    tweettext = str(tweet.full_text.lower().encode('ascii',errors='ignore'))
    if tweettext.startswith("rt @") == False and hasattr(tweet, 'retweeted_status') == False:
        print(tweet.user.id, tweet.created_at, tweet.id, tweet.full_text)
        csvWriter.writerow([tweet.created_at, tweet.full_text.encode('utf-8')])
csvFile.close()
# Out:
# 862695559 2021-04-17 12:00:51 1383389992802668553 @Dhany_AMF12 Tapi kayaknya itu satpol pp kota ****** sih jadi bukan area saya, suka berlebihan emang kota yg pengen dijuluki kota ****** ini 😌
# 97229795 2021-04-17 12:00:00 1383389780180758536 Hey @anggiavii09 bisa-bisanya gue di unfoll 💩 follback! Jangan sampe gue kirim Satpol PP kerumah lo ya
# 1952471238 2021-04-17 11:58:33 1383389413661544458 @Sofy_Beeeeee @Namaku_Mei pak satpol PP kl puasanya ihklas dan bener" sesuai akidah dan anjuran.jangan ada warung nasi didepan mata gw pun pak satpol PP makan dan minum gw ga akan kesambet utk batalin puasa. org yg masih ngelihat makanan dan minuman dianggap godaan iman itu artinya puasanya ga khusyu.
# 213204035 2021-04-17 11:56:15 1383388836340723713 Personel Satpol PP Jakpus Dikerahkan Pantau Prokes Selama Ramadan
#
# #BacadiBJ
# #BeritaJakarta
# #DKIJakarta
# #JAKI
#
# https://t.co/BOBIE0oJcw
# 567649185 2021-04-17 11:56:03 1383388785971322881 Tak ada FPI, satpol pp pun jadi
# ...
